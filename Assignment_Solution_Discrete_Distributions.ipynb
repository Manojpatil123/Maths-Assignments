# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojpatil123/Assignments/blob/main/Assignment_Solution_Discrete_Distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Complete these problems by hand in a piece of paper and then upload in a text cell.**

# %% [markdown]
# # Problem 1

# %% [markdown]
# What is the probability that at least 9 out of a group of 10 people who have been infected by a serious disease will survive, if the survival probability for the disease is 70%?

# %% [markdown]
# X = number of people survived
#
# n = 10
#
# p = 0.7
#
# X can be modelled by a binomial distribution.
#
# X ~ Bin(10, 0.7)
#
# Required probability = P(X>=9) = P(X = 9) + P(X = 10)
#
# = $[C(10,9) \times (0.7)^{9} \times (1 - 0.7)^{1}] + [C(10,10) \times (0.7)^{10} \times (1 - 0.7)^{0}] = 0.1493$

# %% [markdown]
# # Problem 2

# %% [markdown]
# If the probability of having a male or female child is equal, what is the probability that a
# woman’s fourth child is her first son?

# %% [markdown]
# $\theta$ = P(success) = probability of having a son = 0.5
#
# X = number of trials till first success
#
# X can be modelled by Geometric distribution.
#
# X ~ Geometric(0.5)
#
# Required probability = P(X = 4) = $(1-0.5)^{3}\times0.5 = 0.0625 $

# %% [markdown]
# # Problem 3

# %% [markdown]
# If each of the 55 million people in the UK independently has probability $1\times10^{-8}$ of
# being killed by a falling meteorite in a given year, calculate the probability of exactly 2
# such deaths occurring in a given year.

# %% [markdown]
# ![Screenshot 2020-11-25 at 11.48.53 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 4

# %% [markdown]
# The number of home insurance claims a company receives in a month is distributed as a Poisson random variable with mean 2. Calculate the probability that the company receives exactly 30 claims in a year.

# %% [markdown]
# ![Screenshot 2020-11-25 at 11.49.35 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 5

# %% [markdown]
# What is a negative binomial distribution? Write its PDF, mean and variance. (Internet Search)

# %% [markdown]
# ![Screenshot 2020-11-25 at 11.50.43 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 6

# %% [markdown]
# What is a hypergeometric distribution? Write its PDF, mean and variance. (Internet Search)

# %% [markdown]
# ![Screenshot 2020-11-25 at 11.52.01 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2020-11-25 at 11.52.32 AM.png](data:image/png;base64,...)
