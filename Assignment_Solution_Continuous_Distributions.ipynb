# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojpatil123/Assignments/blob/main/Assignment_Solution_Continuous_Distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Complete Problem 2, 3 and 8 by hand in a piece of paper and then upload in a text cell. For the rest of the problems, use Python to calculate the probabilities.**

# %%
from scipy.stats import uniform
from scipy.stats import norm
from scipy.stats import chi2
from scipy.stats import t
from scipy.stats import f
import math

# %% [markdown]
# # Problem 1

# %% [markdown]
# ![Screenshot 2020-11-25 at 7.06.51 PM.png](data:image/png;base64,...)

# %%
lower_limit = 50
upper_limit = 150
range = upper_limit - lower_limit

# %%
# P(Y > 74) = 1 - P(Y < 74)

1 - uniform.cdf(74, lower_limit, range)
# Out:
# 0.76

# %%
# P(50 < Y < 126) = P(Y < 126) - P(Y < 50)

uniform.cdf(126, lower_limit, range) - uniform.cdf(50, lower_limit, range)
# Out:
# 0.76

# %% [markdown]
# # Problem 2

# %% [markdown]
# ![Screenshot 2020-11-25 at 7.06.09 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2020-11-27 at 4.04.32 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 3

# %% [markdown]
# ![Screenshot 2020-11-25 at 7.08.09 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2020-11-27 at 4.05.09 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 4

# %% [markdown]
# ![Screenshot 2020-11-25 at 7.08.45 PM.png](data:image/png;base64,...)

# %%
# Degree of freedom is 5
degree_of_freedom = 5

# %%
# (a) P(X > 6.5) = 1 - P(X < 6.5)

1 - chi2.cdf(6.5, degree_of_freedom)
# Out:
# 0.26055845591074567

# %%
# (b) P(X < 11.8)

chi2.cdf(11.8, degree_of_freedom)
# Out:
# 0.9623665751126652

# %% [markdown]
# # Problem 5

# %% [markdown]
# ![Screenshot 2020-11-25 at 7.09.30 PM.png](data:image/png;base64,...)

# %%
# X ~ N(25, 36) 
mean = 25
standard_deviation = math.sqrt(36)

# (i) P(X < 28)

norm.cdf(28, mean, standard_deviation)
# Out:
# 0.6914624612740131

# %%
# (ii) P(X > 30) = 1 - P(X < 30)

1 - norm.cdf(30, mean, standard_deviation)
# Out:
# 0.20232838096364314

# %%
# (iii) P(X < 20)

norm.cdf(20, mean, standard_deviation)
# Out:
# 0.20232838096364308

# %%
# |X - 25| < 4 
# => (X - 25) < 4 or -(X - 25) < 4
# => X < 29 or X > 21

# (iv) P(|X - 25| < 4) = P(21 < X < 29) = P(X < 29) - P(X < 21)

norm.cdf(29, mean, standard_deviation) - norm.cdf(21, mean, standard_deviation)
# Out:
# 0.4950149249061542

# %% [markdown]
# # Problem 6

# %% [markdown]
# Calculate

# %% [markdown]
# ![Screenshot 2020-11-25 at 7.10.08 PM.png](data:image/png;base64,...)

# %%
# (i) P(X < 1.341)

degree_of_freedom = 15

t.cdf(1.341, degree_of_freedom)
# Out:
# 0.9000625642353094

# %%
# (ii) P(X > a) = 0.01 => P(X < a) = 1 - 0.01 = 0.99

degree_of_freedom = 8

t.ppf(0.99, degree_of_freedom)
# Out:
# 2.896459442760522

# %%
# (i) P(X < -0.5314)

degree_of_freedom = 24

t.cdf(-0.5314, degree_of_freedom)
# Out:
# 0.30001298093526907

# %% [markdown]
# # Problem 7

# %% [markdown]
# Calculate

# %% [markdown]
# ![Screenshot 2020-11-25 at 7.11.24 PM.png](data:image/png;base64,...)

# %%
# (i) P(X < 1.341)

n1 = 5
n2 = 12

f.cdf(3.106, n1, n2)
# Out:
# 0.9500057935637745

# %%
# (ii) P(X > a) = 0.01 => P(X < a) = 1 - 0.01 = 0.99

n1 = 7
n2 = 4

f.ppf(0.99, n1, n2)
# Out:
# 14.975757704446693

# %% [markdown]
# # Problem 8
#
# What is a lognormal distribution? Write its PDF, mean and variance.

# %% [markdown]
# ![Screenshot 2020-11-27 at 4.21.24 PM.png](data:image/png;base64,...)
