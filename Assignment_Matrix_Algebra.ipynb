# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojpatil123/Assignments/blob/main/Assignment_Matrix_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Complete these problems by hand in a piece of paper and then upload in a text cell.**

# %% [markdown]
# # Problem 1

# %% [markdown]
# Find the inverse of the following matrix :
# \begin{bmatrix}
# 2 & 1 & 2\\
# 1 & 2 & 1\\
# 3 & 1 & 3
# \end{bmatrix}

# %% [markdown]
# ![IMG_20220511_235427_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 2

# %% [markdown]
# Given a matrix \begin{bmatrix}
# 2 & 0 & 0\\
# 0 & 1 & 0\\
# 0 & 0 & 5
# \end{bmatrix}
#
# find it's eigenvalues.

# %% [markdown]
# ![IMG_20220511_235422.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 3

# %% [markdown]
# You are given three matrices A,B,C respectively
# \begin{bmatrix}
# 1 & 0 & -1 & 2\\
# 0 & 3 & 1 & -1\\
# 2 & 4 & 0 & 3\\
# -3 & 1 & 2 & 4
# \end{bmatrix}
#
# \begin{bmatrix}
# 1 & 2 \\
# 3 & -1\\
# 0 & -1\\
# 4 & 2
# \end{bmatrix}
#
# \begin{bmatrix}
# 3 & 8 & 0 & 5\\
# 1 & 0 & -4 & 8
# \end{bmatrix}
#
# Consider another matrix $D = CAB $ if it exists. Find the value of $D_{22}$

# %% [markdown]
# ![IMG_20220511_235422_2.jpg](data:image/jpeg;base64,...)
